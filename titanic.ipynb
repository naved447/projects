# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
import numpy as np

# %%
con = mysql.connector.connect(
    host = "127.0.0.1",
    port = "3306",
    user = "root",
    password = "Naved@123",
    database = "project")

# %%
def titan(sql):
    res = pd.read_sql_query(sql,con)
    return(res)

# %%
x = titan("select * from titanic1")
x.head()
# Out:
#    PassengerID  Survived  Pclass    LastName                  FirstName  \
# 0            0         0       0        Name                        Sex
# 1            1         0       3     "Braund           Mr. Owen Harris"
# 2            2         1       1    "Cumings   Mrs. John Bradley (Flore
# 3            3         1       3  "Heikkinen               Miss. Laina"
# 4            4         1       1   "Futrelle   Mrs. Jacques Heath (Lily
#
#       Sex  Age  SibSp  ParCh            Ticket     Fare     Cabin Embarked
# 0     Age    0      0      0              Fare   0.0000  Embarked     None
# 1    male   22      1      0         A/5 21171   7.2500                  S
# 2  female   38      1      0          PC 17599  71.2833       C85        C
# 3  female   26      0      0  STON/O2. 3101282   7.9250                  S
# 4  female   35      1      0            113803  53.1000      C123        S

# %%
data = x.iloc[1:,:]
data.head()
# Out:
#    PassengerID  Survived  Pclass    LastName                  FirstName  \
# 1            1         0       3     "Braund           Mr. Owen Harris"
# 2            2         1       1    "Cumings   Mrs. John Bradley (Flore
# 3            3         1       3  "Heikkinen               Miss. Laina"
# 4            4         1       1   "Futrelle   Mrs. Jacques Heath (Lily
# 5            5         0       3      "Allen         Mr. William Henry"
#
#       Sex  Age  SibSp  ParCh            Ticket     Fare Cabin Embarked
# 1    male   22      1      0         A/5 21171   7.2500              S
# 2  female   38      1      0          PC 17599  71.2833   C85        C
# 3  female   26      0      0  STON/O2. 3101282   7.9250              S
# 4  female   35      1      0            113803  53.1000  C123        S
# 5    male   35      0      0            373450   8.0500              S

# %%
df = pd.DataFrame(data = data)
df.head()
# Out:
#    PassengerID  Survived  Pclass    LastName                  FirstName  \
# 1            1         0       3     "Braund           Mr. Owen Harris"
# 2            2         1       1    "Cumings   Mrs. John Bradley (Flore
# 3            3         1       3  "Heikkinen               Miss. Laina"
# 4            4         1       1   "Futrelle   Mrs. Jacques Heath (Lily
# 5            5         0       3      "Allen         Mr. William Henry"
#
#       Sex  Age  SibSp  ParCh            Ticket     Fare Cabin Embarked
# 1    male   22      1      0         A/5 21171   7.2500              S
# 2  female   38      1      0          PC 17599  71.2833   C85        C
# 3  female   26      0      0  STON/O2. 3101282   7.9250              S
# 4  female   35      1      0            113803  53.1000  C123        S
# 5    male   35      0      0            373450   8.0500              S

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b96161e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19b961757f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19b96161cc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b96175e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b96175f60>],
#  'means': []}

# %%
plt.boxplot(df['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b9628de48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19b96296518>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19b9628da20>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b96296ba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b96296ef0>],
#  'means': []}

# %%
df.describe()
# Out:
#        PassengerID    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.810325    0.523008
# std     257.353842    0.486592    0.836071   17.601613    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             ParCh        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204203
# std      0.806057   49.693412
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329000

# %%
sns.barplot(x="Sex", y="Survived", data=df)

# %%
pd.isnull(df).sum()
# Out:
# PassengerID    0
# Survived       0
# Pclass         0
# LastName       0
# FirstName      0
# Sex            0
# Age            0
# SibSp          0
# ParCh          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.distplot(df['Age'])

# %%
titan("select Age, count(Age) from titanic1 group by Age")
# Out:
#     Age  count(Age)
# 0     0         179
# 1    22          27
# 2    38          11
# 3    26          18
# 4    35          19
# 5    54           8
# 6     2          10
# 7    27          18
# 8    14           6
# 9     4          10
# 10   58           5
# 11   20          15
# 12   39          14
# 13   55           2
# 14   31          19
# 15   34          15
# 16   15           6
# 17   28          25
# 18    8           4
# 19   19          25
# 20   40          13
# 21   66           1
# 22   42          13
# 23   21          25
# 24   18          26
# 25    3           6
# 26    7           3
# 27   49           6
# 28   29          22
# 29   65           3
# ..  ...         ...
# 41   24          31
# 42   46           5
# 43   59           2
# 44   71           3
# 45   37           7
# 46   47           9
# 47   12           1
# 48    9           8
# 49   51           7
# 50   56           5
# 51   41           8
# 52   44           9
# 53   61           3
# ...

# %%
#total survived females
total_surv_female = df[df['Sex'] == 'female']['Survived']
total_surv_female.sum()
# Out:
# 233

# %%
total_surv_males = df[df['Sex'] == 'male']['Survived'].sum()
total_surv_males
# Out:
# 109

# %%
df.drop("Ticket",axis=1,inplace=True)
df.head()
# Out:
#    PassengerID  Survived  Pclass    LastName                  FirstName  \
# 1            1         0       3     "Braund           Mr. Owen Harris"
# 2            2         1       1    "Cumings   Mrs. John Bradley (Flore
# 3            3         1       3  "Heikkinen               Miss. Laina"
# 4            4         1       1   "Futrelle   Mrs. Jacques Heath (Lily
# 5            5         0       3      "Allen         Mr. William Henry"
#
#       Sex  Age  SibSp  ParCh     Fare Cabin Embarked
# 1    male   22      1      0   7.2500              S
# 2  female   38      1      0  71.2833   C85        C
# 3  female   26      0      0   7.9250              S
# 4  female   35      1      0  53.1000  C123        S
# 5    male   35      0      0   8.0500              S

# %%
sns.barplot(x="Sex",y="Survived",data=df)

# %%
sns.distplot(df['Fare'])

# %%
sns.barplot(x="Pclass",y="Survived",data=df)

# %%
sns.barplot(x="Pclass",y="Survived",hue="Sex",data=df)

# %%
sns.barplot(x="Pclass",y="Survived",hue="Age",data=df)

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    PassengerID  Survived  Pclass    LastName                  FirstName  \
# 1            1         0       3     "Braund           Mr. Owen Harris"
# 2            2         1       1    "Cumings   Mrs. John Bradley (Flore
# 3            3         1       3  "Heikkinen               Miss. Laina"
# 4            4         1       1   "Futrelle   Mrs. Jacques Heath (Lily
# 5            5         0       3      "Allen         Mr. William Henry"
#
#       Sex  Age  SibSp  ParCh     Fare Cabin Embarked
# 1    male   22      1      0   7.2500              S
# 2  female   38      1      0  71.2833   C85        C
# 3  female   26      0      0   7.9250              S
# 4  female   35      1      0  53.1000  C123        S
# 5    male   35      0      0   8.0500              S

# %%
sns.barplot(x="ParCh",y="Survived",data=df)

# %%
sns.barplot(x="SibSp",y="Survived",data=df)
