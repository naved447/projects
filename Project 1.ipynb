# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd
import numpy as np

# %%
con = mysql.connector.connect(
    host = "127.0.0.1",
    port = "3306",
    user = "root",
    password = "Naved@123",
    database = "result")

# %%
df = pd.read_sql_query("Select * from studmarks",con)
df
# Out:
#    Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0     0      M    5/4/1988     55       45         56       87       21
# 1     0      M    4/5/1987     75       96         78       64       90
# 2     0      M  25-05-1989     25       54         89       76       95
# 3     0      F   12/8/1990     78       96         86       63       54
# 4     0      F    2/9/1989     58       96         78       46       96
# 5     0      F    5/4/1988     45       87         52       89       55
# 6     0      F    4/5/1987     55       64         61       58       75
# 7     0      M  25-05-1989     54       76         87       56       25
# 8     0      F   12/8/1990     55       63         89       75       78
# 9     0      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# ...

# %%
stud = pd.read_sql_query("Select * from studentmarks",con)
stud
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
def studresult(sql):
    res = pd.read_sql_query(sql,con)
    return(res)

# %%
studresult('select * from studentmarks')
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
studresult("select Name from studentmarks")
# Out:
#        Name
# 0      John
# 1    Suresh
# 2    Ramesh
# 3   Jessica
# 4  Jennifer
# 5      Annu
# 6     pooja
# 7    Ritesh
# 8     Farha
# 9    Mukesh

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
df = pd.DataFrame(data=stud)

# %%
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
plt.boxplot(df['Maths'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1859016cbe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x185901832b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1859016c780>],
#  'medians': [<matplotlib.lines.Line2D at 0x18590183940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18590183c88>],
#  'means': []}

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
sns.heatmap(df.isnull())

# %%
plt.boxplot(df['Civics'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1859046de48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x185904787b8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1859046dcf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x18590478e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18590478f28>],
#  'means': []}

# %%
dfcorr=df.corr()

# %%
dfcorr
# Out:
#               Maths   Physics  Chemistry   English   Biology  Economics  \
# Maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             History    Civics
# Maths     -0.320846 -0.274629
# Physics    0.334082 -0.643266
# Chemistry -0.482710  0.210908
# English   -0.038775  0.186705
# Biology   -0.456131 -0.330060
# Economics -0.164953  0.043905
# History    1.000000 -0.048686
# Civics    -0.048686  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(dfcorr,cmap='Reds',annot=True)

# %%
df_new=df.iloc[:,3:]
df_new
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics
# 0     55       45         56       87       21         52       89      65
# 1     75       96         78       64       90         61       58       2
# 2     25       54         89       76       95         87       56      74
# 3     78       96         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
# 5     45       87         52       89       55         89       87      52
# 6     55       64         61       58       75         58       64      61
# 7     54       76         87       56       25         56       76      87
# 8     55       63         89       75       78         75       63      89
# 9     96       46         77       83       58         83       46      77

# %%
z=np.abs(zscore(df_new))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
dfnew=df_new[(z<3).all(axis=1)]

# %%
dfnew.shape
# Out:
# (10, 8)

# %%
df_new.shape
# Out:
# (10, 8)

# %%
sns.barplot(x="Gender",y="Maths",data=df)

# %%
sns.barplot(x="Name",y="Maths",hue="Gender",data=df)
