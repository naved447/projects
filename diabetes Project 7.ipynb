# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_diabetes

# %%
diab=load_diabetes()

# %%
diab.keys()
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
diab.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
diab.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
diab.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df=pd.DataFrame(data=diab.data,columns=diab.feature_names)

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
diab.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
df['DiseaseProgression']=diab.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  DiseaseProgression
# 0 -0.002592  0.019908 -0.017646               151.0
# 1 -0.039493 -0.068330 -0.092204                75.0
# 2 -0.002592  0.002864 -0.025930               141.0
# 3  0.034309  0.022692 -0.009362               206.0
# 4 -0.002592 -0.031991 -0.046641               135.0

# %%
df.shape
# Out:
# (442, 11)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
sns.heatmap(df.isnull())

# %%
plt.boxplot(df['bp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2131a2592e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2131a259978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2131a50feb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2131a259d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2131a266390>],
#  'means': []}

# %%
plt.boxplot(df['bmi'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2131a438550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2131a438be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2131a438128>],
#  'medians': [<matplotlib.lines.Line2D at 0x2131a438fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2131a43f5f8>],
#  'means': []}

# %%
sns.pairplot(x_vars=["age","sex","bmi","bp","s1","s2","s3","s4","s5","s6"],y_vars="DiseaseProgression",data=df,kind="reg",aspect=0.7,height=10)

# %%
df.shape
# Out:
# (442, 11)

# %%
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (430, 11)

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
#from sklearn.cross_validation import cross_val_score

# %%
lr=LinearRegression()

# %%
score=cross_val_score(lr,x,y,cv=5)
score
# Out:
# array([0.43165329, 0.53324907, 0.44058787, 0.3982216 , 0.53474379])

# %%
score.mean()
# Out:
# 0.4676911221693185

# %%
score.std()
# Out:
# 0.0559521778584194

# %%
def dia(a):
    score=cross_val_score(lr,x,y,cv=a)
#    print(mod)
    print('\nScore\n',score)
    print('\nMean\n',score.mean())
    print('\nStandar Deviation\n',score.std())
    print("\n Variance\n",score.var())
dia(4)
# Out:
# Score
#  [0.38738228 0.49078899 0.47507999 0.53061692]
#
# Mean
#  0.47096704564094033
#
# Standar Deviation
#  0.05233150661168218
#
#  Variance
#  0.0027385865842485353

# %%
dia(7)
# Out:
# Score
#  [0.45526059 0.38021601 0.58506194 0.44603346 0.44208667 0.3891271
#  0.59713628]
#
# Mean
#  0.4707031508125262
#
# Standar Deviation
#  0.08068617555850263
#
#  Variance
#  0.006510258926257508

# %%
dia(5)
# Out:
# Score
#  [0.43165329 0.53324907 0.44058787 0.3982216  0.53474379]
#
# Mean
#  0.4676911221693185
#
# Standar Deviation
#  0.0559521778584194
#
#  Variance
#  0.003130646207100198
